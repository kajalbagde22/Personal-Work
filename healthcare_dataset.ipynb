# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("../DataSets/healthcare-dataset-stroke-data (1).csv")

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
df.age.unique()
# Out:
# array([6.70e+01, 6.10e+01, 8.00e+01, 4.90e+01, 7.90e+01, 8.10e+01,
#        7.40e+01, 6.90e+01, 5.90e+01, 7.80e+01, 5.40e+01, 5.00e+01,
#        6.40e+01, 7.50e+01, 6.00e+01, 5.70e+01, 7.10e+01, 5.20e+01,
#        8.20e+01, 6.50e+01, 5.80e+01, 4.20e+01, 4.80e+01, 7.20e+01,
#        6.30e+01, 7.60e+01, 3.90e+01, 7.70e+01, 7.30e+01, 5.60e+01,
#        4.50e+01, 7.00e+01, 6.60e+01, 5.10e+01, 4.30e+01, 6.80e+01,
#        4.70e+01, 5.30e+01, 3.80e+01, 5.50e+01, 1.32e+00, 4.60e+01,
#        3.20e+01, 1.40e+01, 3.00e+00, 8.00e+00, 3.70e+01, 4.00e+01,
#        3.50e+01, 2.00e+01, 4.40e+01, 2.50e+01, 2.70e+01, 2.30e+01,
#        1.70e+01, 1.30e+01, 4.00e+00, 1.60e+01, 2.20e+01, 3.00e+01,
#        2.90e+01, 1.10e+01, 2.10e+01, 1.80e+01, 3.30e+01, 2.40e+01,
#        3.40e+01, 3.60e+01, 6.40e-01, 4.10e+01, 8.80e-01, 5.00e+00,
#        2.60e+01, 3.10e+01, 7.00e+00, 1.20e+01, 6.20e+01, 2.00e+00,
#        9.00e+00, 1.50e+01, 2.80e+01, 1.00e+01, 1.80e+00, 3.20e-01,
#        1.08e+00, 1.90e+01, 6.00e+00, 1.16e+00, 1.00e+00, 1.40e+00,
#        1.72e+00, 2.40e-01, 1.64e+00, 1.56e+00, 7.20e-01, 1.88e+00,
#        1.24e+00, 8.00e-01, 4.00e-01, 8.00e-02, 1.48e+00, 5.60e-01,
#        4.80e-01, 1.60e-01])

# %%
df.age = df.age.replace('.','',regex=True).astype('int64')

# %%
df.gender.unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
bmi_mean = df['bmi'].mean()
df['bmi'].fillna(bmi_mean,inplace=True)
df
# Out:
#          id  gender  age  hypertension  heart_disease ever_married  \
# 0      9046    Male   67             0              1          Yes
# 1     51676  Female   61             0              0          Yes
# 2     31112    Male   80             0              1          Yes
# 3     60182  Female   49             0              0          Yes
# 4      1665  Female   79             1              0          Yes
# ...     ...     ...  ...           ...            ...          ...
# 5105  18234  Female   80             1              0          Yes
# 5106  44873  Female   81             0              0          Yes
# 5107  19723  Female   35             0              0          Yes
# 5108  37544    Male   51             0              0          Yes
# 5109  44679  Female   44             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# 1     Self-employed          Rural             202.21  28.893237
# 2           Private          Rural             105.92  32.500000
# 3           Private          Urban             171.23  34.400000
# 4     Self-employed          Rural             174.12  24.000000
# ...             ...            ...                ...        ...
# 5105        Private          Urban              83.75  28.893237
# 5106  Self-employed          Urban             125.20  40.000000
# 5107  Self-employed          Rural              82.99  30.600000
# 5108        Private          Rural             166.29  25.600000
# 5109       Govt_job          Urban              85.28  26.200000
#
#        smoking_status  stroke
# 0     formerly smoked       1
# 1        never smoked       1
# 2        never smoked       1
# 3              smokes       1
# 4        never smoked       1
# ...               ...     ...
# 5105     never smoked       0
# 5106     never smoked       0
# 5107     never smoked       0
# 5108  formerly smoked       0
# 5109          Unknown       0
#
# [5110 rows x 12 columns]

# %%
df.id.unique()
# Out:
# array([ 9046, 51676, 31112, ..., 19723, 37544, 44679], dtype=int64)

# %%
q1 = np.percentile(df.age,25)
q3 = np.percentile(df.age,75)
iqr = q3-q1
c2 = q1-(1.5*iqr)
c1 = q3+(1.5*iqr)
t = df[(df.age < c2)| (df.age > c1)]
t
# Out:
# Empty DataFrame
# Columns: [id, gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %%
q1 = np.percentile(df.avg_glucose_level,25)
q3 = np.percentile(df.avg_glucose_level,75)
iqr = q3-q1
c2 = q1-(1.5*iqr)
c1 = q3+(1.5*iqr)
t = df[(df.avg_glucose_level < c2)| (df.avg_glucose_level > c1)]
t
# Out:
#          id  gender  age  hypertension  heart_disease ever_married  \
# 0      9046    Male   67             0              1          Yes
# 1     51676  Female   61             0              0          Yes
# 3     60182  Female   49             0              0          Yes
# 4      1665  Female   79             1              0          Yes
# 5     56669    Male   81             0              0          Yes
# ...     ...     ...  ...           ...            ...          ...
# 5061  38009    Male   41             0              0          Yes
# 5062  11184  Female   82             0              0          Yes
# 5063  68967    Male   39             0              0          Yes
# 5064  66684    Male   70             0              0          Yes
# 5076  39935  Female   34             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# 1     Self-employed          Rural             202.21  28.893237
# 3           Private          Urban             171.23  34.400000
# 4     Self-employed          Rural             174.12  24.000000
# 5           Private          Urban             186.21  29.000000
# ...             ...            ...                ...        ...
# 5061        Private          Urban             223.78  32.300000
# 5062  Self-employed          Rural             211.58  36.900000
# 5063        Private          Urban             179.38  27.700000
# 5064  Self-employed          Rural             193.88  24.300000
# 5076        Private          Rural             174.37  23.000000
#
#        smoking_status  stroke
# 0     formerly smoked       1
# 1        never smoked       1
# 3              smokes       1
# 4        never smoked       1
# 5     formerly smoked       1
# ...               ...     ...
# 5061     never smoked       0
# 5062     never smoked       0
# 5063          Unknown       0
# 5064          Unknown       0
# 5076     never smoked       0
#
# [627 rows x 12 columns]

# %%
q1 = np.percentile(df.bmi,25)
q3 = np.percentile(df.bmi,75)
iqr = q3-q1
c2 = q1-(1.5*iqr)
c1 = q3+(1.5*iqr)
t = df[(df.bmi < c2)| (df.bmi > c1)]
t
# Out:
#          id  gender  age  hypertension  heart_disease ever_married  \
# 21    13861  Female   52             1              0          Yes
# 66    17004  Female   70             0              0          Yes
# 113   41069  Female   45             0              0          Yes
# 254   32257  Female   47             0              0          Yes
# 258   28674  Female   74             1              0          Yes
# ...     ...     ...  ...           ...            ...          ...
# 4906  72696  Female   53             0              0          Yes
# 4952  16245    Male   51             1              0          Yes
# 5009  40732  Female   50             0              0          Yes
# 5057  38349  Female   49             0              0          Yes
# 5103  22127  Female   18             0              0           No
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 21    Self-employed          Urban             233.29  48.9     never smoked
# 66          Private          Urban             221.58  47.5     never smoked
# 113         Private          Rural             224.10  56.6     never smoked
# 254         Private          Urban             210.95  50.1          Unknown
# 258   Self-employed          Urban             205.84  54.6     never smoked
# ...             ...            ...                ...   ...              ...
# 4906        Private          Urban              70.51  54.1     never smoked
# 4952  Self-employed          Rural             211.83  56.6     never smoked
# 5009  Self-employed          Rural             126.85  49.5  formerly smoked
# 5057       Govt_job          Urban              69.92  47.6     never smoked
# 5103        Private          Urban              82.85  46.9          Unknown
#
#       stroke
# 21         1
# 66         1
# 113        1
# 254        0
# 258        0
# ...      ...
# 4906       0
# 4952       0
# 5009       0
# 5057       0
# 5103       0
#
# [126 rows x 12 columns]

# %%
data_encoded = pd.get_dummies(df,columns=['gender', 'ever_married','work_type','Residence_type','smoking_status'])

# %%
data_encoded
# Out:
#          id  age  hypertension  heart_disease  avg_glucose_level        bmi  \
# 0      9046   67             0              1             228.69  36.600000
# 1     51676   61             0              0             202.21  28.893237
# 2     31112   80             0              1             105.92  32.500000
# 3     60182   49             0              0             171.23  34.400000
# 4      1665   79             1              0             174.12  24.000000
# ...     ...  ...           ...            ...                ...        ...
# 5105  18234   80             1              0              83.75  28.893237
# 5106  44873   81             0              0             125.20  40.000000
# 5107  19723   35             0              0              82.99  30.600000
# 5108  37544   51             0              0             166.29  25.600000
# 5109  44679   44             0              0              85.28  26.200000
#
#       stroke  gender_Female  gender_Male  gender_Other  ...  \
# 0          1          False         True         False  ...
# 1          1           True        False         False  ...
# 2          1          False         True         False  ...
# 3          1           True        False         False  ...
# 4          1           True        False         False  ...
# ...      ...            ...          ...           ...  ...
# 5105       0           True        False         False  ...
# 5106       0           True        False         False  ...
# 5107       0           True        False         False  ...
# 5108       0          False         True         False  ...
# 5109       0           True        False         False  ...
#
#       work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 0                      False               True                    False
# 1                      False              False                     True
# 2                      False               True                    False
# 3                      False               True                    False
# 4                      False              False                     True
# ...                      ...                ...                      ...
# 5105                   False               True                    False
# 5106                   False              False                     True
# 5107                   False              False                     True
# 5108                   False               True                    False
# 5109                   False              False                    False
#
#       work_type_children  Residence_type_Rural  Residence_type_Urban  \
# 0                  False                 False                  True
# 1                  False                  True                 False
# 2                  False                  True                 False
# 3                  False                 False                  True
# 4                  False                  True                 False
# ...                  ...                   ...                   ...
# 5105               False                 False                  True
# 5106               False                 False                  True
# 5107               False                  True                 False
# 5108               False                  True                 False
# 5109               False                 False                  True
#
#       smoking_status_Unknown  smoking_status_formerly smoked  \
# 0                      False                            True
# 1                      False                           False
# 2                      False                           False
# 3                      False                           False
# 4                      False                           False
# ...                      ...                             ...
# 5105                   False                           False
# 5106                   False                           False
# 5107                   False                           False
# 5108                   False                            True
# 5109                    True                           False
#
#       smoking_status_never smoked  smoking_status_smokes
# 0                           False                  False
# 1                            True                  False
# 2                            True                  False
# 3                           False                   True
# 4                            True                  False
# ...                           ...                    ...
# 5105                         True                  False
# 5106                         True                  False
# 5107                         True                  False
# 5108                        False                  False
# 5109                        False                  False
#
# [5110 rows x 23 columns]

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.215264      0.097456       0.054012
# std    21161.721625    22.633866      0.296607       0.226063
# min       67.000000     0.000000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  5110.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.698018     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.800000     0.000000
# 50%            91.885000    28.400000     0.000000
# 75%           114.090000    32.800000     0.000000
# max           271.740000    97.600000     1.000000

# %%
#median
df.bmi.median()
# Out:
# 28.4

# %%
fig=plt.figure(figsize=(16, 10))

fig.add_subplot(231)
sb.histplot(df.age,kde=True)
plt.title('Age Distribution')

fig.add_subplot(232)
sb.histplot(df.avg_glucose_level,kde=True)
plt.title('Avg Glucose Level Distribution')

fig.add_subplot(233)
sb.histplot(df.bmi,kde=True)
plt.title('BMI Distribution')
# Out:
# Text(0.5, 1.0, 'BMI Distribution')

# %%
fig=plt.figure(figsize=(16, 10))

fig.add_subplot(231)
sb.boxplot(df['age'])
plt.title('Age Distribution')

fig.add_subplot(232)
sb.boxplot(df['avg_glucose_level'])
plt.title('Avg Glucose Level Distribution')

fig.add_subplot(233)
sb.boxplot(df['bmi'])
plt.title('BMI Distribution')
# Out:
# Text(0.5, 1.0, 'BMI Distribution')

# %%
fig=plt.figure(figsize=(16, 10))

fig.add_subplot(231)
sb.kdeplot(df['age'])
plt.title('Age Distribution')

fig.add_subplot(232)
sb.kdeplot(df['avg_glucose_level'])
plt.title('Avg Glucose Level Distribution')

fig.add_subplot(233)
sb.kdeplot(df['bmi'])
plt.title('BMI Distribution')
# Out:
# Text(0.5, 1.0, 'BMI Distribution')

# %%
df.corr(numeric_only=True)
# Out:
#                          id       age  hypertension  heart_disease  \
# id                 1.000000  0.003503      0.003550      -0.001296
# age                0.003503  1.000000      0.276303       0.263668
# hypertension       0.003550  0.276303      1.000000       0.108306
# heart_disease     -0.001296  0.263668      0.108306       1.000000
# avg_glucose_level  0.001092  0.238060      0.174474       0.161857
# bmi                0.002999  0.326271      0.160189       0.038899
# stroke             0.006388  0.245128      0.127904       0.134914
#
#                    avg_glucose_level       bmi    stroke
# id                          0.001092  0.002999  0.006388
# age                         0.238060  0.326271  0.245128
# hypertension                0.174474  0.160189  0.127904
# heart_disease               0.161857  0.038899  0.134914
# avg_glucose_level           1.000000  0.168751  0.131945
# bmi                         0.168751  1.000000  0.038947
# stroke                      0.131945  0.038947  1.000000

# %%
corr_matrix = df[['id','age','hypertension','heart_disease','avg_glucose_level','bmi','stroke']].corr()
plt.figure(figsize=(10, 8))
sb.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix')
plt.show()

# %%
categorical_columns = ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']
categorical_columns
# Out:
# ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']

# %%
fig=plt.figure(figsize=(18, 9))

fig.add_subplot(231)
sb.countplot(x='gender',data=df)
plt.title('Distribution og Gender')

fig.add_subplot(232)
sb.countplot(x='ever_married',data=df)
plt.title('Distribution of ever_married')

fig.add_subplot(233)
sb.countplot(x='work_type',data=df)
plt.title('Distribution of work_type')

fig.add_subplot(234)
sb.countplot(x='Residence_type',data=df)
plt.title('Distribution of Residence_type')

fig.add_subplot(235)
sb.countplot(x='smoking_status',data=df)
plt.title('Distribution of smoking_status')
plt.show()

# %% [markdown]
# Groupby / Crosstab / Pivot_table
#
# Basic Group By:
#
# Group the data by gender and calculate the mean age for each gender.

# %%
df.groupby('gender')['age'].mean().reset_index()
# Out:
#    gender        age
# 0  Female  43.748497
# 1    Male  42.468558
# 2   Other  26.000000

# %% [markdown]
# Group the data by work_type and calculate the count of individuals in each work type.

# %%
df.groupby('work_type').size().reset_index()
# Out:
#        work_type     0
# 0       Govt_job   657
# 1   Never_worked    22
# 2        Private  2925
# 3  Self-employed   819
# 4       children   687

# %% [markdown]
# Multiple Aggregations:
#
# Group the data by Residence_type and calculate the mean and standard deviation of avg_glucose_level and bmi for each residence type.

# %%
a = df.groupby('Residence_type').agg({'avg_glucose_level': ['mean', 'std'],'bmi': ['mean', 'std']})
a
# Out:
#                avg_glucose_level                   bmi
#                             mean        std       mean       std
# Residence_type
# Rural                 106.375235  45.218348  28.894176  7.766954
# Urban                 105.927307  45.354246  28.892328  7.632162

# %% [markdown]
# Group the data by smoking_status and stroke and calculate the average age and bmi.

# %%
b = df.groupby(['smoking_status', 'stroke']).agg({ 'age': 'mean','bmi': 'mean'}).reset_index()
b
# Out:
#     smoking_status  stroke        age        bmi
# 0          Unknown       0  29.073480  25.687648
# 1          Unknown       1  65.829787  29.176133
# 2  formerly smoked       0  53.753374  30.648912
# 3  formerly smoked       1  68.628571  30.620173
# 4     never smoked       0  45.567703  29.940716
# 5     never smoked       1  70.311111  30.336216
# 6           smokes       0  46.212851  30.433425
# 7           smokes       1  62.809524  30.459041

# %% [markdown]
# Conditional Group By:
#
# Group the data by hypertension and calculate the proportion of individuals who have had a stroke.

# %%
df.groupby('hypertension')['stroke'].mean().reset_index()
# Out:
#    hypertension    stroke
# 0             0  0.039679
# 1             1  0.132530

# %% [markdown]
# Group the data by heart_disease and calculate the mean age for individuals with and without strokes.

# %%
df.groupby(['heart_disease', 'stroke'])['age'].mean().reset_index()
# Out:
#    heart_disease  stroke        age
# 0              0       0  40.699698
# 1              0       1  66.777228
# 2              1       0  67.445415
# 3              1       1  71.808511

# %% [markdown]
# Custom Aggregations:
#
# Group the data by work_type and aggregate the following:
# Mean avg_glucose_level
# Maximum age
# Count of stroke occurrences

# %%
c = df.groupby('work_type').agg(
    mean_avg_glucose_level=('avg_glucose_level', 'mean'),
    max_age=('age', 'max'),
    count_stroke=('stroke', 'sum')
).reset_index()

# %%
c
# Out:
#        work_type  mean_avg_glucose_level  max_age  count_stroke
# 0       Govt_job              107.779772       82            33
# 1   Never_worked               96.042727       23             0
# 2        Private              106.796844       82           149
# 3  Self-employed              112.645446       82            65
# 4       children               94.400277       16             2

# %% [markdown]
# Crosstab Questions
#
# Basic Crosstab:
# Create a crosstab showing the count of strokes for each combination of gender and heart_disease, segmented by stroke status.

# %%
pd.crosstab(index=df.gender, columns=df.work_type, values=df.stroke, aggfunc='sum', margins=True)
# Out:
# work_type  Govt_job  Never_worked  Private  Self-employed  children  All
# gender
# Female         23.0           0.0     76.0           40.0       2.0  141
# Male           10.0           0.0     73.0           25.0       0.0  108
# Other           NaN           NaN      0.0            NaN       NaN    0
# All            33.0           0.0    149.0           65.0       2.0  249

# %% [markdown]
# Create a crosstab showing the proportion (normalized) of strokes for each combination of

# %%
pd.crosstab(index=df.Residence_type, columns=df.smoking_status, values=df.stroke, aggfunc='mean', margins=True)
# Out:
# smoking_status   Unknown  formerly smoked  never smoked    smokes       All
# Residence_type
# Rural           0.023622         0.079439      0.045786  0.049587  0.045346
# Urban           0.037084         0.078775      0.049409  0.056338  0.052003
# All             0.030440         0.079096      0.047569  0.053232  0.048728

# %% [markdown]
# Advanced Crosstab:
#
# Create a crosstab showing the mean age for each combination of hypertension and
# heart_disease, segmented by stroke status.

# %%
pd.crosstab(index=[df['hypertension'],df['heart_disease']],columns=df.stroke,values=df.age,aggfunc='mean',margins=True)
# Out:
# stroke                              0          1        All
# hypertension heart_disease
# 0            0              38.985650  65.778523  39.892955
#              1              66.707865  71.441176  67.466981
# 1            0              59.824147  69.584906  61.016129
#              1              70.019608  72.769231  70.578125
# All                         41.959679  67.726908  43.215264

# %% [markdown]
# Create a crosstab showing the total number of individuals (count) for each combination of
# ever_married and work_type, adding margins to include row and column totals.

# %%
pd.crosstab(index=df.ever_married,columns=df.work_type, margins=True)
# Out:
# work_type     Govt_job  Never_worked  Private  Self-employed  children   All
# ever_married
# No                 117            22      821            110       687  1757
# Yes                540             0     2104            709         0  3353
# All                657            22     2925            819       687  5110

# %% [markdown]
# Crosstab with Custom Aggregations:
# Create a crosstab showing the sum of stroke occurrences for each combination of gender
# and Residence_type.

# %%
pd.crosstab(index=df.gender, columns=df.Residence_type, values=df.stroke, aggfunc='sum', margins=True)
# Out:
# Residence_type  Rural  Urban  All
# gender
# Female           64.0   77.0  141
# Male             50.0   58.0  108
# Other             0.0    NaN    0
# All             114.0  135.0  249

# %% [markdown]
# Create a crosstab that displays the mean bmi for each combination of work_type and
# smoking_status.

# %%
pd.crosstab(index=df.work_type, columns=df.smoking_status, values=df.bmi, aggfunc='mean', margins=True)
# Out:
# smoking_status    Unknown  formerly smoked  never smoked     smokes        All
# work_type
# Govt_job        29.805405        31.187614     30.246995  30.792939  30.455125
# Never_worked    22.037500              NaN     27.550000        NaN  25.545455
# Private         29.839839        30.809047     30.150425  30.406746  30.249617
# Self-employed   29.503413        30.496758     30.146562  30.331713  30.141029
# children        19.924108        20.876403     23.655556  22.950000  20.244238
# All             25.793839        30.646639     29.959529  30.434789  28.893237

# %% [markdown]
# Pivot Table Questions
# Basic Pivot Table:
#
# Create a pivot table showing the mean avg_glucose_level for each combination of gender
# and Residence_type.

# %%
a = pd.pivot_table(data=df,index='gender',columns='Residence_type',values='avg_glucose_level',aggfunc='mean',margins=True)
a
# Out:
# Residence_type       Rural       Urban         All
# gender
# Female          104.056860  104.058718  104.057809
# Male            109.580830  108.604977  109.088520
# Other           143.330000         NaN  143.330000
# All             106.375235  105.927307  106.147677

# %% [markdown]
# Create a pivot table showing the count of strokes for each work_type, segmented by
# hypertension.

# %%
b = pd.pivot_table(data=df,index='work_type',columns='hypertension',values='stroke',aggfunc='count',margins=True)
b
# Out:
# hypertension        0      1   All
# work_type
# Govt_job        584.0   73.0   657
# Never_worked     22.0    NaN    22
# Private        2644.0  281.0  2925
# Self-employed   675.0  144.0   819
# children        687.0    NaN   687
# All            4612.0  498.0  5110

# %% [markdown]
# Multiple Aggregations in Pivot Table:
#
# Create a pivot table that shows the mean and median age for each combination of
# smoking_status and ever_married.

# %%
c = pd.pivot_table(df,values='age',index=['smoking_status','ever_married'],aggfunc=['mean','median'],margins=True)
c
# Out:
#                                    mean median
#                                     age    age
# smoking_status  ever_married
# Unknown         No            13.148724      9
#                 Yes           54.074650     53
# formerly smoked No            36.034014     30
#                 Yes           58.693767     59
# never smoked    No            29.320755     23
#                 Yes           53.524963     53
# smokes          No            33.167598     28
#                 Yes           51.183607     51
# All                           43.215264     45

# %% [markdown]
# Create a pivot table with work_type and gender as the index, and calculate the mean,
# minimum, and maximum bmi.

# %%
d = pd.pivot_table(df,values='bmi',index=['work_type','gender'],aggfunc=['mean','min','max'],margins=True)
d
# Out:
#                            mean   min   max
#                             bmi   bmi   bmi
# work_type     gender
# Govt_job      Female  30.285711  16.0  57.2
#               Male    30.717127  18.1  57.7
# Never_worked  Female  26.054545  20.4  44.9
#               Male    25.036364  14.6  41.8
# Private       Female  30.258477  14.1  78.0
#               Male    30.243043  11.5  97.6
#               Other   22.400000  22.4  22.4
# Self-employed Female  29.704796  11.3  56.0
#               Male    30.839000  18.8  64.8
# children      Female  20.217667  10.3  41.7
#               Male    20.268234  13.0  38.7
# All                   28.893237  10.3  97.6

# %% [markdown]
# Pivot Table with Custom Functions:
#
# Create a pivot table that shows the percentage of strokes for each combination of work_type
# and Residence_type. Use a custom lambda function to calculate the percentage

# %%
e = pd.pivot_table(df,index=['work_type','Residence_type'],values='stroke',aggfunc=lambda x: (x.sum ()/ len(x)) * 100)
e
# Out:
#                                 stroke
# work_type     Residence_type
# Govt_job      Rural           4.487179
#               Urban           5.507246
# Never_worked  Rural           0.000000
#               Urban           0.000000
# Private       Rural           4.651163
#               Urban           5.536569
# Self-employed Rural           7.888041
#               Urban           7.981221
# children      Rural           0.294118
#               Urban           0.288184

# %% [markdown]
# Data Visualization Questions
#
# Histograms:
#
# Create a histogram to visualize the distribution of age. Describe the distribution.

# %%
plt.figure(figsize=(12,6))
sb.histplot(df['age'])
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Plot a histogram of avg_glucose_level. What does the distribution tell you about the glucose
# levels in the dataset?

# %%
plt.figure(figsize=(12,6))
sb.histplot(df['avg_glucose_level'])
plt.title('Distribution of Avg_glucose_level')
plt.xlabel('Avg Glucose level')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Bar Plots:
#
# Create a bar plot showing the count of individuals in each work_type. What can you infer
# from this plot?

# %%
work_type_counts = df.work_type.value_counts()
plt.figure(figsize=(12,6))
sb.barplot(x=work_type_counts.index,y=work_type_counts.values)
plt.title('Count of Individual of Each Work Type')
plt.xlabel('work_type')
plt.ylabel('count')
plt.show()

# %% [markdown]
# Create a bar plot of the number of strokes (stroke) for each Residence_type. How do the
# stroke counts compare between urban and rural areas?

# %%
stroke_count_by_residence= df.groupby('Residence_type')['stroke'].sum()
plt.figure(figsize=(10,5))
sb.barplot(x=stroke_count_by_residence.index,y=stroke_count_by_residence)
plt.title('Number of strokes by Residence Type')
plt.xlabel('Residence_type')
plt.ylabel('Number of stroke')
plt.show()

# %% [markdown]
# Box Plots:
#
# Create a box plot to show the distribution of bmi for each smoking_status. What does the
# box plot reveal about BMI across different smoking statuses?

# %%
plt.figure(figsize=(10, 6))
sb.boxplot(x='smoking_status', y='bmi', data=df)
plt.title('BMI Distribution by Smoking Status')
plt.xlabel('Smoking Status')
plt.ylabel('BMI')
plt.show()

# %% [markdown]
# Create a box plot to visualize the avg_glucose_level for each hypertension status. Discuss
# any observed differences.

# %%
plt.figure(figsize=(10, 6))
sb.boxplot(x='hypertension', y='avg_glucose_level', data=df)
plt.title('Avg Glucose Level Distribution by Hypertension Status')
plt.xlabel('Hypertension Status')
plt.ylabel('Avg Glucose Level')
plt.show()

# %% [markdown]
# Scatter Plots:
#
# Create a scatter plot showing the relationship between age and avg_glucose_level. Use
# different colors to distinguish between individuals who had a stroke and those who did not

# %%
plt.figure(figsize=(10, 6))
sb.scatterplot(data=df, x='age', y='avg_glucose_level')
plt.title('Scatter Plot of Age vs. Avg Glucose Level')
plt.xlabel('Age')
plt.ylabel('Avg Glucose Level')
plt.legend(title='Stroke')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Create a scatter plot to examine the relationship between bmi and avg_glucose_level. Color
# the points based on stroke status.

# %%
plt.figure(figsize=(10, 6))
sb.scatterplot(data=df, x='bmi', y='avg_glucose_level', hue='stroke', palette={0: 'blue', 1: 'red'})
plt.title('Scatter Plot of BMI vs. Avg Glucose Level')
plt.xlabel('BMI')
plt.ylabel('Avg Glucose Level')
plt.legend(title='Stroke')
plt.show()

# %% [markdown]
# Heatmaps:
#
# Create a heatmap to visualize the correlation matrix of the numerical variables (age,
# avg_glucose_level, bmi). Discuss any strong correlations you observe.

# %%
plt.figure(figsize=(10, 6))
correlation_matrix = df[['age', 'avg_glucose_level', 'bmi']].corr()
sb.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# Count Plots:
#
# Create a count plot for gender, displaying the number of individuals who had a stroke versus
# those who did not.

# %%
sb.countplot(df,x='gender')
plt.title('Stroke count of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
sb.countplot(df,x='ever_married')
plt.title('Stroke count of Marital Status')
plt.xlabel('Ever_')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Pair Plots:
#
# Create a pair plot for the variables age, avg_glucose_level, and bmi, colored by stroke
# status. What relationships and patterns do you observe?

# %%
sb.pairplot(df, vars=['age', 'avg_glucose_level', 'bmi'], hue='stroke', palette={0: 'blue', 1: 'red'})
plt.suptitle('Pair Plot of Age, Avg Glucose Level, and BMI', y=1.02)
plt.show()
# Out:
# C:\Users\Payal\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Violin Plots:
#
# Create a violin plot to visualize the distribution of age for each stroke status. How do the
# distributions compare?

# %%
plt.figure(figsize=(10, 6))
sb.violinplot(data=df, x='stroke', y='age', palette='muted')
plt.title('Violin Plot of Age by Stroke Status')
plt.xlabel('Stroke')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# Create a violin plot to show the distribution of avg_glucose_level for different work_type
# categories. Discuss any notable findings.

# %%
plt.figure(figsize=(12, 8))
sb.violinplot(data=df, x='work_type', y='avg_glucose_level', palette='muted')
plt.title('Violin Plot of Avg Glucose Level by Work Type')
plt.xlabel('Work Type')
plt.ylabel('Avg Glucose Level')
plt.show()

# %% [markdown]
# Pie Charts:
#
# Create a pie chart showing the proportion of each gender in the dataset.

# %%
gender_counts = df['gender'].value_counts()
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140, colors=['lightblue', 'lightpink'])
plt.title('Proportion of Each Gender in the Dataset')
plt.axis('equal')
plt.show()

# %% [markdown]
# Create a pie chart to visualize the distribution of Residence_type in the dataset.

# %%
residence_counts = df['Residence_type'].value_counts()
plt.pie(residence_counts, labels=residence_counts.index, autopct='%1.1f%%', startangle=140, colors=['lightgreen', 'lightcoral'])
plt.title('Distribution of Residence Type in the Dataset')
plt.axis('equal')
plt.show()
